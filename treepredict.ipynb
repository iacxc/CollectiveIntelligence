# %%
from imp import reload
import treepredict
reload(treepredict)

#print(treepredict.giniimpurity(treepredict.my_data))
#print(treepredict.entropy(treepredict.my_data))
#set1,set2 = treepredict.divideset(treepredict.my_data, 2, 'yes')
#print(treepredict.entropy(set1))
#print(treepredict.giniimpurity(set1))
tree = treepredict.buildtree(treepredict.my_data)
treepredict.printtree(tree, '   ')
treepredict.drawtree(tree)
treepredict.classify(['(direct)', 'UK', 'no', 5], tree)
# Out:
# 0:google?
#    T-> 3:21?
#       T-> Counter({'Premium': 3})
#       F-> 2:no?
#          T-> Counter({'None': 1})
#          F-> Counter({'Basic': 1})
#    F-> 0:slashdot?
#       T-> Counter({'None': 3})
#       F-> 2:no?
#          T-> 3:21?
#             T-> Counter({'Basic': 1})
#             F-> Counter({'None': 3})
#          F-> Counter({'Basic': 4})
# Counter({'None': 3})
